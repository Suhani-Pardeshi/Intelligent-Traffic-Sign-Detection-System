# %%
import cv2
import numpy as np
import gradio as gr

def detect_traffic_sign(image):
    img = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # ---------- COLOR RANGES ----------
    red1 = cv2.inRange(hsv, (0,70,50), (10,255,255))
    red2 = cv2.inRange(hsv, (170,70,50), (180,255,255))
    red_mask = red1 + red2

    yellow_mask = cv2.inRange(hsv, (20,100,100), (35,255,255))
    green_mask = cv2.inRange(hsv, (36,50,50), (89,255,255))
    blue_mask = cv2.inRange(hsv, (90,50,50), (130,255,255))

    # ---------- PIXEL COUNT ----------
    r, y, g, b = map(np.sum, [red_mask, yellow_mask, green_mask, blue_mask])

    # ---------- SHAPE DETECTION ----------
    blur = cv2.GaussianBlur(gray, (5,5), 0)
    edges = cv2.Canny(blur, 50, 150)
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    for cnt in contours:
        approx = cv2.approxPolyDP(cnt, 0.04 * cv2.arcLength(cnt, True), True)
        area = cv2.contourArea(cnt)

        if area < 1000:
            continue

        # STOP sign (octagon)
        if len(approx) == 8 and r > 50000:
            return "🛑 STOP SIGN"

        # NO ENTRY (circle + red)
        if len(approx) > 8 and r > 60000:
            return "⛔ NO ENTRY SIGN"

        # SPEED LIMIT (circle)
        if len(approx) > 8 and r > 30000:
            return "🚫 SPEED LIMIT SIGN"

    # ---------- TRAFFIC SIGNAL ----------
    if r > y and r > g:
        return "🔴 RED SIGNAL – STOP"
    elif y > r and y > g:
        return "🟡 YELLOW SIGNAL – READY"
    elif g > r and g > y:
        return "🟢 GREEN SIGNAL – GO"

    # ---------- PEDESTRIAN ----------
    if b > 40000:
        return "🚸 PEDESTRIAN CROSSING"

    return "⚠️ Traffic Sign Not Detected"


# ---------- GRADIO UI ----------
interface = gr.Interface(
    fn=detect_traffic_sign,
    inputs=gr.Image(type="numpy", label="Upload Traffic Sign Image"),
    outputs=gr.Textbox(label="Detected Traffic Sign"),
    title="🚦 Multi Traffic Sign Detection System",
    description="Detect Traffic Signal, Stop, No Entry, Pedestrian & Speed Limit signs"
)

interface.launch()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import cv2
#       2 import numpy as np
# ----> 3 import gradio as gr
#       5 def detect_traffic_sign(image):
#       6     img = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
#
# ModuleNotFoundError: No module named 'gradio'

# %%
pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-6.5.0-py3-none-any.whl.metadata (16 kB)
# Collecting aiofiles<25.0,>=22.0 (from gradio)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\suhani\anaconda3\lib\site-packages (from gradio) (4.7.0)
# Requirement already satisfied: audioop-lts<1.0 in c:\users\suhani\anaconda3\lib\site-packages (from gradio) (0.2.2)
# Collecting brotli>=1.1.0 (from gradio)
#   Downloading brotli-1.2.0-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\suhani\anaconda3\lib\site-packages (from gradio) (0.121.0)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-1.0.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==2.0.3 (from gradio)
#   Downloading gradio_client-2.0.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\suhani\anaconda3\lib\site-packages (from gradio) (0.28.1)
# Collecting huggingface-hub<2.0,>=0.33.5 (from gradio)
#   Downloading huggingface_hub-1.3.5-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: jinja2<4.0 in c:\users\suhani\anaconda3\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\suhani\anaconda3\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\suhani\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.11.5-cp313-cp313-win_amd64.whl.metadata (42 kB)
# Requirement already satisfied: packaging in c:\users\suhani\anaconda3\lib\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<4.0,>=1.0 in c:\users\suhani\anaconda3\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in c:\users\suhani\anaconda3\lib\site-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in c:\users\suhani\anaconda3\lib\site-packages (from gradio) (2.10.3)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.22-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\suhani\anaconda3\lib\site-packages (from gradio) (6.0.2)
# Collecting safehttpx<0.2.0,>=0.1.7 (from gradio)
#   Downloading safehttpx-0.1.7-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\suhani\anaconda3\lib\site-packages (from gradio) (0.49.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\suhani\anaconda3\lib\site-packages (from gradio) (0.13.2)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.21.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\suhani\anaconda3\lib\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\suhani\anaconda3\lib\site-packages (from gradio) (0.38.0)
# Requirement already satisfied: fsspec in c:\users\suhani\anaconda3\lib\site-packages (from gradio-client==2.0.3->gradio) (2025.3.2)
# Requirement already satisfied: idna>=2.8 in c:\users\suhani\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\suhani\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\suhani\anaconda3\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.3)
# Requirement already satisfied: certifi in c:\users\suhani\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\suhani\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\suhani\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in c:\users\suhani\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.17.0)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub<2.0,>=0.33.5->gradio)
#   Downloading hf_xet-1.2.0-cp37-abi3-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: shellingham in c:\users\suhani\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.5.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\suhani\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Collecting typer-slim (from huggingface-hub<2.0,>=0.33.5->gradio)
#   Downloading typer_slim-0.21.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\suhani\anaconda3\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\suhani\anaconda3\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\suhani\anaconda3\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\suhani\anaconda3\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\suhani\anaconda3\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (2.27.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\suhani\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: rich>=10.11.0 in c:\users\suhani\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: colorama in c:\users\suhani\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\suhani\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\suhani\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\suhani\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\suhani\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Downloading gradio-6.5.0-py3-none-any.whl (24.2 MB)
#    ---------------------------------------- 0.0/24.2 MB ? eta -:--:--
#    ------------- -------------------------- 8.4/24.2 MB 48.6 MB/s eta 0:00:01
#    ------------------- -------------------- 11.8/24.2 MB 31.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 13.6/24.2 MB 24.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 14.2/24.2 MB 18.6 MB/s eta 0:00:01
#    ------------------------ --------------- 14.9/24.2 MB 14.9 MB/s eta 0:00:01
#    -------------------------- ------------- 16.0/24.2 MB 12.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 17.0/24.2 MB 11.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 18.1/24.2 MB 11.1 MB/s eta 0:00:01
#    -------------------------------- ------- 19.7/24.2 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 21.0/24.2 MB 10.1 MB/s eta 0:00:01
#    -------------------------------------- - 23.1/24.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------- 24.2/24.2 MB 9.8 MB/s eta 0:00:00
# Downloading gradio_client-2.0.3-py3-none-any.whl (55 kB)
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading huggingface_hub-1.3.5-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.7 kB ? eta -:--:--
#    ---------------------------------------- 536.7/536.7 kB 5.3 MB/s eta 0:00:00
# Downloading hf_xet-1.2.0-cp37-abi3-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------- ----------- 2.1/2.9 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 10.8 MB/s eta 0:00:00
# Downloading orjson-3.11.5-cp313-cp313-win_amd64.whl (133 kB)
# Downloading safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading typer-0.21.1-py3-none-any.whl (47 kB)
# Downloading brotli-1.2.0-cp313-cp313-win_amd64.whl (369 kB)
# Downloading python_multipart-0.0.22-py3-none-any.whl (24 kB)
# Downloading ffmpy-1.0.0-py3-none-any.whl (5.6 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading typer_slim-0.21.1-py3-none-any.whl (47 kB)
# Installing collected packages: pydub, brotli, semantic-version, python-multipart, orjson, hf-xet, groovy, ffmpy, aiofiles, typer-slim, typer, safehttpx, huggingface-hub, gradio-client, gradio
#
#   Attempting uninstall: brotli
#
#     Found existing installation: Brotli 1.0.9
#
#     Uninstalling Brotli-1.0.9:
#
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#    -- -------------------------------------  1/15 [brotli]
#       Successfully uninstalled Brotli-1.0.9
#    -- -------------------------------------  1/15 [brotli]
#    -------- -------------------------------  3/15 [python-multipart]
#    --------------------- ------------------  8/15 [aiofiles]
#   Attempting uninstall: typer
#    --------------------- ------------------  8/15 [aiofiles]
#     Found existing installation: typer 0.9.0
#    --------------------- ------------------  8/15 [aiofiles]
#     Uninstalling typer-0.9.0:
#    --------------------- ------------------  8/15 [aiofiles]
#       Successfully uninstalled typer-0.9.0
#    --------------------- ------------------  8/15 [aiofiles]
#    -------------------------- ------------- 10/15 [typer]
#    -------------------------------- ------- 12/15 [huggingface-hub]
#    -------------------------------- ------- 12/15 [huggingface-hub]
#    -------------------------------- ------- 12/15 [huggingface-hub]
#    -------------------------------- ------- 12/15 [huggingface-hub]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ---------------------------------------- 15/15 [gradio]
#
# Successfully installed aiofiles-24.1.0 brotli-1.2.0 ffmpy-1.0.0 gradio-6.5.0 gradio-client-2.0.3 groovy-0.1.2 hf-xet-1.2.0 huggingface-hub-1.3.5 orjson-3.11.5 pydub-0.25.1 python-multipart-0.0.22 safehttpx-0.1.7 semantic-version-2.10.0 typer-0.21.1 typer-slim-0.21.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import gradio as gr

def detect_traffic_sign(image):
    img = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # ---------- COLOR RANGES ----------
    red1 = cv2.inRange(hsv, (0,70,50), (10,255,255))
    red2 = cv2.inRange(hsv, (170,70,50), (180,255,255))
    red_mask = red1 + red2

    yellow_mask = cv2.inRange(hsv, (20,100,100), (35,255,255))
    green_mask = cv2.inRange(hsv, (36,50,50), (89,255,255))
    blue_mask = cv2.inRange(hsv, (90,50,50), (130,255,255))

    # ---------- PIXEL COUNT ----------
    r, y, g, b = map(np.sum, [red_mask, yellow_mask, green_mask, blue_mask])

    # ---------- SHAPE DETECTION ----------
    blur = cv2.GaussianBlur(gray, (5,5), 0)
    edges = cv2.Canny(blur, 50, 150)
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    for cnt in contours:
        approx = cv2.approxPolyDP(cnt, 0.04 * cv2.arcLength(cnt, True), True)
        area = cv2.contourArea(cnt)

        if area < 1000:
            continue

        # STOP sign (octagon)
        if len(approx) == 8 and r > 50000:
            return "🛑 STOP SIGN"

        # NO ENTRY (circle + red)
        if len(approx) > 8 and r > 60000:
            return "⛔ NO ENTRY SIGN"

        # SPEED LIMIT (circle)
        if len(approx) > 8 and r > 30000:
            return "🚫 SPEED LIMIT SIGN"

    # ---------- TRAFFIC SIGNAL ----------
    if r > y and r > g:
        return "🔴 RED SIGNAL – STOP"
    elif y > r and y > g:
        return "🟡 YELLOW SIGNAL – READY"
    elif g > r and g > y:
        return "🟢 GREEN SIGNAL – GO"

    # ---------- PEDESTRIAN ----------
    if b > 40000:
        return "🚸 PEDESTRIAN CROSSING"

    return "⚠️ Traffic Sign Not Detected"


# ---------- GRADIO UI ----------
interface = gr.Interface(
    fn=detect_traffic_sign,
    inputs=gr.Image(type="numpy", label="Upload Traffic Sign Image"),
    outputs=gr.Textbox(label="Detected Traffic Sign"),
    title="🚦 Multi Traffic Sign Detection System",
    description="Detect Traffic Signal, Stop, No Entry, Pedestrian & Speed Limit signs"
)

interface.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Created dataset file at: .gradio\flagged\dataset1.csv
